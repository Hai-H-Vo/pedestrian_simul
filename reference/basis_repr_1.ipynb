# %%
# IMPORTS

import numpy as onp
import jax.numpy as np
import optax
from jax import random
from jax import jit
from jax import vmap
from jax import grad
from jax import lax
from jax import config
config.update("jax_enable_x64", True)
config.update('jax_debug_nans', True)
config.update('jax_traceback_filtering', 'off')

from jax_md import space, smap, energy, minimize, quantity, simulate, partition, util
from jax_md.util import f32

from collections import namedtuple

vectorize = np.vectorize

from functools import partial
from simulator.utils import ttc_force, _normalize
from simulator.force import general_force_generator
from simulator.render import render
from simulator.dynamics import pedestrian, PedestrianState, StraightWall

# %%
# POSITIONS AND VELOCITIES
POS_NUMS = 2
ANGLE_NUMS = 2
R = 0.1
K = 1.5
T_0 = 3.0
V_2_MAG = 1.
CYCLE_NUMS = 1000

positions = np.stack([np.linspace(0.3, 2., POS_NUMS), np.zeros([POS_NUMS,])], axis=1)
angles = np.linspace(0, 1/2, ANGLE_NUMS)
v_2 = V_2_MAG * np.stack([np.cos(onp.pi * angles), np.sin(onp.pi * angles)], axis=1)
v_1 = np.zeros([ANGLE_NUMS, 2])

# %%
# PARAMS INIT
paral_weights = np.ones([10, 10, 10])
perpen_weights = np.ones([10, 10, 10])
d_0 = 10.
v_0 = 10.

def _loss_fn(params, pos, v1, v2):
    paral_weights = params['paral']
    perpen_weights = params['perpen']
    v_0 = params['v0']
    d_0 = params['d0']
    return np.linalg.norm(general_force_generator(paral_weights, perpen_weights, v_0, d_0)(pos, v1, v2) - ttc_force(pos, v1, v2, R, K, T_0)) ** 2

def loss_fn(params, pos, v1, v2):
    # loss_fn = sum over sets of (pos, v) ||F_pred - F||^2
    full_loss_fn = vmap(vmap(_loss_fn, (None, None, 0, 0)), (None, 0, None, None))
    return np.sum(full_loss_fn(params, pos, v1, v2))

# %%
# OPTIMIZATION
start_learning_rate = 0.1
optimizer = optax.adam(start_learning_rate)

# PARAMS
params = {'paral' : paral_weights,
          'perpen' : perpen_weights,
          'd0' : d_0,
          'v0' : v_0}
opt_state = optimizer.init(params)

# %%
loss_fn(params, positions, v_1, v_2)
# Out:
# /Users/vohoanghai/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/ops/scatter.py:108: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=int64 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# Array(2.54108976e+41, dtype=float64)

# %%
# UPDATE LOOP
for i in range(CYCLE_NUMS):
  print(f"Current update loop: {i}/{CYCLE_NUMS}")
  print(f"Current loss: {loss_fn(params, positions, v_1, v_2)}")
  grads = grad(loss_fn)(params, positions, v_1, v_2)
  # fails before this point
  updates, opt_state = optimizer.update(grads, opt_state)
  params = optax.apply_updates(params, updates)
# Out:
# Current update loop: 0/1000
# Current loss: 2.5410897621699358e+41
# Current update loop: 1/1000
# Current loss: 1.615593515834843e+41
# Current update loop: 2/1000
# Current loss: 1.1488173994291905e+41
# Current update loop: 3/1000
# Current loss: 1.0704131864393428e+41
# Current update loop: 4/1000
# Current loss: 7.828423765735825e+40
# Current update loop: 5/1000
# Current loss: 1.072952334892542e+41
# Current update loop: 6/1000
# Current loss: 7.583370539510201e+40
# Current update loop: 7/1000
# Current loss: 4.955658073126851e+40
# Current update loop: 8/1000
# Current loss: 2.9065403806286126e+40
# Current update loop: 9/1000
# Current loss: 1.4426209100003102e+40
# Current update loop: 10/1000
# Current loss: 5.3657556679993155e+39
# Current update loop: 11/1000
# Current loss: 1.294229636573991e+39
# Current update loop: 12/1000
# Current loss: 1.3115193476344079e+39
# Current update loop: 13/1000
# Current loss: 3.8342065806760303e+39
# Current update loop: 14/1000
# Current loss: 7.676349215646842e+39
# Current update loop: 15/1000
# Current loss: 1.1863763920110686e+40
# Current update loop: 16/1000
# Current loss: 2.969976518115272e+39
# Current update loop: 17/1000
# Current loss: 2.9147223500776223e+39
# Current update loop: 18/1000
# Current loss: 2.1576374758119388e+39
# Current update loop: 19/1000
# Current loss: 5.908974725316888e+39
# Current update loop: 20/1000
# Current loss: 2.0128739617859261e+40
# Current update loop: 21/1000
# Current loss: 1.9565104260352521e+40
# Current update loop: 22/1000
# Current loss: 1.5010835286393178e+40
# Current update loop: 23/1000
# Current loss: 5.796368688953673e+39
# Current update loop: 24/1000
# Current loss: 5.317277246618499e+39
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:678, in run_forever()
#     677 while True:
# --> 678     self._run_once()
#     679     if self._stopping:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:2033, in _run_once()
#    2032     else:
# -> 2033         handle._run()
#    2034 handle = None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py:89, in _run()
#      88 try:
# ---> 89     self._context.run(self._callback, *self._args)
#      90 except (SystemExit, KeyboardInterrupt):
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:545, in dispatch_queue()
#     544 try:
# --> 545     await self.process_one()
#     546 except Exception:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:534, in process_one()
#     533         return
# --> 534 await dispatch(*args)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:437, in dispatch_shell()
#     436     if inspect.isawaitable(result):
# --> 437         await result
#     438 except Exception:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py:362, in execute_request()
#     361 self._associate_new_top_level_threads_with(parent_header)
# --> 362 await super().execute_request(stream, ident, parent)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:778, in execute_request()
#     777 if inspect.isawaitable(reply_content):
# --> 778     reply_content = await reply_content
#     780 # Flush output before sending the reply.
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py:449, in do_execute()
#     448 if accepts_params["cell_id"]:
# --> 449     res = shell.run_cell(
#     450         code,
#     451         store_history=store_history,
#     452         silent=silent,
#     453         cell_id=cell_id,
#     454     )
#     455 else:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/ipykernel/zmqshell.py:549, in run_cell()
#     548 self._last_traceback = None
# --> 549 return super().run_cell(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3100, in run_cell()
#    3099 try:
# -> 3100     result = self._run_cell(
#    3101         raw_cell, store_history, silent, shell_futures, cell_id
#    3102     )
#    3103 finally:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3155, in _run_cell()
#    3154 try:
# -> 3155     result = runner(coro)
#    3156 except BaseException as e:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3367, in run_cell_async()
#    3364 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3367 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3368        interactivity=interactivity, compiler=compiler, result=result)
#    3370 self.last_execution_succeeded = not has_raised
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3612, in run_ast_nodes()
#    3611     asy = compare(code)
# -> 3612 if await self.run_code(code, result, async_=asy):
#    3613     return True
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3672, in run_code()
#    3671     else:
# -> 3672         exec(code_obj, self.user_global_ns, self.user_ns)
#    3673 finally:
#    3674     # Reset our crash handler in place
#
# Cell In[6], line 5
#       4 print(f"Current loss: {loss_fn(params, positions, v_1, v_2)}")
# ----> 5 grads = grad(loss_fn)(params, positions, v_1, v_2)
#       6 # fails before this point
#
# Cell In[3], line 17, in loss_fn()
#      16 full_loss_fn = vmap(vmap(_loss_fn, (None, None, 0, 0)), (None, 0, None, None))
# ---> 17 return np.sum(full_loss_fn(params, pos, v1, v2))
#
# Cell In[3], line 12, in _loss_fn()
#      11 d_0 = params['d0']
# ---> 12 return np.linalg.norm(general_force_generator(paral_weights, perpen_weights, v_0, d_0)(pos, v1, v2) - ttc_force(pos, v1, v2, R, K, T_0)) ** 2
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/force.py:112, in general_force()
#     110 # force calc
#     111 force = (general_force_magnitude(scaled_v, scaled_pos, proj, weight_paral_arr) * unit_v +
# --> 112         general_force_magnitude(scaled_v, scaled_pos, proj, weight_perpen_arr) * np.matmul(np.identity(2) - np.matmul(unit_v, np.transpose(unit_v)), unit_pos))
#     114 return force
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/force.py:91, in general_force_magnitude()
#      90 lag_j = lax.scan(partial(updater, poly_type=True, val=scaled_pos), lag_j, lag_j)[0]
# ---> 91 leg_k = lax.scan(partial(updater, poly_type=False, val=proj), leg_k, leg_k)[0]
#      93 expansion = weight_arr * np.tensordot(np.tensordot(lag_i, lag_j, axes=0), leg_k, axes=0)
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/force.py:86, in updater()
#      81 def updater(arr, idx, poly_type, val):
#      82    # True == Laguerre
#      83    # False == Legendre
#      84    new_arr = np.where(poly_type,
#      85                       arr.at[idx].set(LaguerreBase(idx)(val)),
# ---> 86                       arr.at[idx].set(LegendreBase(idx)(val)))
#      87    return new_arr, idx
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/basis.py:105, in __call__()
#     104 # final_val = lax.while_loop(cond_fun, body_fun, init_val)
# --> 105 final_val = lax.fori_loop(2, self.degree + 1, body_fun, init_val)
#     107 return final_val['result']
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 print(f"Current update loop: {i}/{CYCLE_NUMS}")
#       4 print(f"Current loss: {loss_fn(params, positions, v_1, v_2)}")
# ----> 5 grads = grad(loss_fn)(params, positions, v_1, v_2)
#       6 # fails before this point
#       7 updates, opt_state = optimizer.update(grads, opt_state)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api.py:437, in grad.<locals>.grad_f(*args, **kwargs)
#     434 @wraps(fun, docstr=docstr, argnums=argnums)
#     435 @api_boundary
#     436 def grad_f(*args, **kwargs):
# --> 437   _, g = value_and_grad_f(*args, **kwargs)
#     438   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api.py:510, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     508   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     509 if not has_aux:
# --> 510   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     511 else:
#     512   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api.py:2179, in _vjp(fun, has_aux, *primals)
#    2177 if not has_aux:
#    2178   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2179   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2180   out_tree = out_tree()
#    2181 else:
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:292, in vjp(traceable, primals, has_aux)
#     290 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     291   if not has_aux:
# --> 292     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     293   else:
#     294     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:277, in linearize(traceable, *primals, **kwargs)
#     275 _, in_tree = tree_flatten(((primals, primals), {}))
#     276 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 277 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     278 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     279 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:614, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     612 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     613 with core.set_current_trace(trace):
# --> 614   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     615   assert not env
#     616 del trace, fun
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:628, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     620 @lu.transformation2
#     621 def trace_to_subjaxpr_nounits(
#     622     f: Callable,
#    (...)    625     debug_info: core.DebugInfo,
#     626     in_pvals: Sequence[PartialVal]):
#     627   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 628   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     629       f, trace, instantiate, in_pvals, debug_info)
#     630   out_pvals = [t.pval for t in out_tracers]
#     631   del out_tracers
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:81, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      78 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      79        else contextlib.nullcontext())
#      80 with ctx:
# ---> 81   out_primals, out_tangents = f(tag, primals, tangents)
#      82 if type(instantiate) is bool:
#      83   instantiate = [instantiate] * len(out_tangents)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:136, in jvp_subtrace(f, tag, primals, tangents)
#     133   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     134                 for x, t in zip(primals, tangents)]
#     135   with core.set_current_trace(trace):
# --> 136     ans = f(*in_tracers)
#     137   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     138 return out
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# Cell In[3], line 17, in loss_fn(params, pos, v1, v2)
#      14 def loss_fn(params, pos, v1, v2):
#      15     # loss_fn = sum over sets of (pos, v) ||F_pred - F||^2
#      16     full_loss_fn = vmap(vmap(_loss_fn, (None, None, 0, 0)), (None, 0, None, None))
# ---> 17     return np.sum(full_loss_fn(params, pos, v1, v2))
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api.py:1129, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1126 try:
#    1127   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1128                                 explicit_mesh_axis)
# -> 1129   out_flat = batching.batch(
#    1130       flat_fun, axis_data, in_axes_flat,
#    1131       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1132   ).call_wrapped(*args_flat)
#    1133 except batching.SpecMatchError as e:
#    1134   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:618, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     616 tag = TraceTag()
#     617 with source_info_util.transform_name_stack('vmap'):
# --> 618   outs, trace = f(tag, in_dims, *in_vals)
#     619 with core.ensure_no_leaks(trace): del trace
#     620 return outs
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:634, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     630   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     631 with (core.set_current_trace(trace),
#     632       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     633       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 634   outs = f(*in_tracers)
#     635   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     636   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     637                  range(len(outs)), outs, out_dim_dests)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:342, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     338 @lu.transformation_with_aux2
#     339 def flatten_fun_for_vmap(f: Callable,
#     340                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     341   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 342   ans = f(*py_args, **py_kwargs)
#     343   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     344   store.store(out_tree)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/api.py:1129, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1126 try:
#    1127   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1128                                 explicit_mesh_axis)
# -> 1129   out_flat = batching.batch(
#    1130       flat_fun, axis_data, in_axes_flat,
#    1131       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1132   ).call_wrapped(*args_flat)
#    1133 except batching.SpecMatchError as e:
#    1134   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:618, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     616 tag = TraceTag()
#     617 with source_info_util.transform_name_stack('vmap'):
# --> 618   outs, trace = f(tag, in_dims, *in_vals)
#     619 with core.ensure_no_leaks(trace): del trace
#     620 return outs
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:634, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     630   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     631 with (core.set_current_trace(trace),
#     632       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     633       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 634   outs = f(*in_tracers)
#     635   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     636   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     637                  range(len(outs)), outs, out_dim_dests)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:342, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     338 @lu.transformation_with_aux2
#     339 def flatten_fun_for_vmap(f: Callable,
#     340                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     341   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 342   ans = f(*py_args, **py_kwargs)
#     343   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     344   store.store(out_tree)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# Cell In[3], line 12, in _loss_fn(params, pos, v1, v2)
#      10 v_0 = params['v0']
#      11 d_0 = params['d0']
# ---> 12 return np.linalg.norm(general_force_generator(paral_weights, perpen_weights, v_0, d_0)(pos, v1, v2) - ttc_force(pos, v1, v2, R, K, T_0)) ** 2
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/force.py:112, in general_force_generator.<locals>.general_force(dpos, V_i, V_j)
#     108 proj = np.dot(dv, dpos) / (scaled_pos * scaled_v)
#     110 # force calc
#     111 force = (general_force_magnitude(scaled_v, scaled_pos, proj, weight_paral_arr) * unit_v +
# --> 112         general_force_magnitude(scaled_v, scaled_pos, proj, weight_perpen_arr) * np.matmul(np.identity(2) - np.matmul(unit_v, np.transpose(unit_v)), unit_pos))
#     114 return force
#
# File ~/Documents/MIT/UROP_1/Work/General Simuls/simulator/force.py:91, in general_force_generator.<locals>.general_force_magnitude(scaled_v, scaled_pos, proj, weight_arr)
#      89 lag_i = lax.scan(partial(updater, poly_type=True, val=scaled_v), lag_i, lag_i)[0]
#      90 lag_j = lax.scan(partial(updater, poly_type=True, val=scaled_pos), lag_j, lag_j)[0]
# ---> 91 leg_k = lax.scan(partial(updater, poly_type=False, val=proj), leg_k, leg_k)[0]
#      93 expansion = weight_arr * np.tensordot(np.tensordot(lag_i, lag_j, axes=0), leg_k, axes=0)
#      95 return np.sum(expansion) * np.exp(-(scaled_v + scaled_pos)/2)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:370, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     364 ext_to_ext_fwd = [
#     365     in_idx - len(consts) if in_idx is not None and
#     366     in_idx >= num_carry + len(consts) else None for in_idx in ext_fwd]
#     367 jaxpr = pe.prune_closed_jaxpr_outputs(
#     368     jaxpr, [True] * num_carry + [i is None for i in ext_to_ext_fwd])
# --> 370 out = scan_p.bind(*consts, *in_flat,
#     371                   reverse=reverse, length=length, jaxpr=jaxpr,
#     372                   num_consts=len(consts), num_carry=num_carry,
#     373                   linear=(False,) * (len(consts) + len(in_flat)),
#     374                   unroll=unroll, _split_transpose=_split_transpose)
#     376 # Apply input to output forwarding that was computed above.
#     377 carry_out, out = split_list(out, [num_carry])
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:498, in BatchTrace.process_primitive(self, p, tracers, params)
#     496   else:
#     497     with core.set_current_trace(self.parent_trace):
# --> 498       val_out, dim_out = fancy_primitive_batchers[p](
#     499           self.axis_data, vals_in, dims_in, **params)
#     500 elif args_not_mapped:
#     501   # no-op shortcut
#     502   return p.bind_with_trace(self.parent_trace, vals_in, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:1206, in _scan_batching_rule(axis_data, args, dims, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#    1202 new_xs = [batching.moveaxis(x, d, 1) if d is not batching.not_mapped and d != 1
#    1203           else x for x, d in zip(xs, xs_bdims)]
#    1204 new_args = new_consts + new_init + new_xs
# -> 1206 outs = scan_p.bind(
#    1207     *new_args, reverse=reverse, length=length, jaxpr=jaxpr_batched,
#    1208     num_consts=num_consts, num_carry=num_carry, linear=linear, unroll=unroll,
#    1209     _split_transpose=_split_transpose)
#    1210 carry_bdims = [0 if b else batching.not_mapped for b in carry_batched]
#    1211 ys_bdims = [1 if b else batching.not_mapped for b in ys_batched]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:498, in BatchTrace.process_primitive(self, p, tracers, params)
#     496   else:
#     497     with core.set_current_trace(self.parent_trace):
# --> 498       val_out, dim_out = fancy_primitive_batchers[p](
#     499           self.axis_data, vals_in, dims_in, **params)
#     500 elif args_not_mapped:
#     501   # no-op shortcut
#     502   return p.bind_with_trace(self.parent_trace, vals_in, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:1206, in _scan_batching_rule(axis_data, args, dims, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#    1202 new_xs = [batching.moveaxis(x, d, 1) if d is not batching.not_mapped and d != 1
#    1203           else x for x, d in zip(xs, xs_bdims)]
#    1204 new_args = new_consts + new_init + new_xs
# -> 1206 outs = scan_p.bind(
#    1207     *new_args, reverse=reverse, length=length, jaxpr=jaxpr_batched,
#    1208     num_consts=num_consts, num_carry=num_carry, linear=linear, unroll=unroll,
#    1209     _split_transpose=_split_transpose)
#    1210 carry_bdims = [0 if b else batching.not_mapped for b in carry_batched]
#    1211 ys_bdims = [1 if b else batching.not_mapped for b in ys_batched]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:500, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     498   raise NotImplementedError(msg)
#     499 with core.set_current_trace(self.parent_trace):
# --> 500   primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     502 if primitive.multiple_results:
#     503   return [maybe_jvp_tracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:695, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#     690 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     691 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     692                          + init_linear + [True] * len(init_dot)
#     693                          + xs_linear + [True] * len(xs_dot))
# --> 695 out_flat = scan_p.bind(
#     696     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     697     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     698     num_consts=num_consts + len(consts_dot),
#     699     num_carry=num_carry + len(init_dot),
#     700     linear=jaxpr_jvp_linear, unroll=unroll,
#     701     _split_transpose=_split_transpose)
#     703 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     704 primals_out = carry + ys
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:229, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     227 if primitive in custom_partial_eval_rules:
#     228   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 229   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     230 else:
#     231   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:867, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *tracers)
#     864 other_pvals = [pe.PartialVal.unknown(aval)
#     865                for aval in jaxpr_known.in_avals[len(const_pvals):]]
#     866 with source_info_util.reset_name_stack():
# --> 867   jaxpr_known_, invar_pvals_out, jaxpr_known_consts = pe.trace_to_jaxpr_nounits(
#     868       lu.wrap_init(core.jaxpr_as_fun(jaxpr_known),
#     869                    debug_info=jaxpr_known.jaxpr.debug_info),
#     870       const_pvals + other_pvals,
#     871       instantiate=[True] * (len(out_uk) - sum(out_uk)) + [False] * num_res)
#     872 jaxpr_known = pe.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr_known_), ())
#     873 # The above trace_to_jaxpr_nounits call computed loop-invariant residuals
#     874 # (known values in invar_pvals_out) and also computed loop-invariant values
#     875 # needed by the new jaxpr_known (in jaxpr_known_consts, which replace the
#     876 # previous consts). We need to collect the computed intensive residuals, and
#     877 # move corresponding intensive residual binders in jaxpr_unknown to the front.
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:614, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     612 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     613 with core.set_current_trace(trace):
# --> 614   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     615   assert not env
#     616 del trace, fun
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:628, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     620 @lu.transformation2
#     621 def trace_to_subjaxpr_nounits(
#     622     f: Callable,
#    (...)    625     debug_info: core.DebugInfo,
#     626     in_pvals: Sequence[PartialVal]):
#     627   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 628   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     629       f, trace, instantiate, in_pvals, debug_info)
#     630   out_pvals = [t.pval for t in out_tracers]
#     631   del out_tracers
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:661, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     659 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     660 with core.set_current_trace(trace):
# --> 661   ans = f(*in_args)
#     662 assert isinstance(ans, (list, tuple)), (
#     663     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     664 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     665     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:296, in jaxpr_as_fun(closed_jaxpr, *args)
#     287 @curry
#     288 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
#     289   # TODO(dougalm): remove this hack when we add contexts to jaxpr.
#    (...)    293   # context modifications. In the meantime, disabling the checks when we
#     294   # round-trip prevents those ops producing spurious errors.
#     295   with config.debug_nans(False):
# --> 296     return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:630, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     627 traceback = eqn.source_info.traceback if propagate_source_info else None
#     628 with source_info_util.user_context(
#     629     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 630   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     631 if eqn.primitive.multiple_results:
#     632   foreach(write, eqn.outvars, ans)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:536, in Primitive.bind(self, *args, **params)
#     534 def bind(self, *args, **params):
#     535   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 536   return self._true_bind(*args, **params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:552, in Primitive._true_bind(self, *args, **params)
#     550 trace_ctx.set_trace(eval_trace)
#     551 try:
# --> 552   return self.bind_with_trace(prev_trace, args, params)
#     553 finally:
#     554   trace_ctx.set_trace(prev_trace)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/core.py:562, in Primitive.bind_with_trace(self, trace, args, params)
#     559   with set_current_trace(trace):
#     560     return self.to_lojax(*args, **params)  # type: ignore
# --> 562 return trace.process_primitive(self, args, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:229, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     227 if primitive in custom_partial_eval_rules:
#     228   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 229   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     230 else:
#     231   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:1968, in _while_partial_eval(trace, cond_nconsts, cond_jaxpr, body_nconsts, body_jaxpr, *tracers)
#    1962 cond_jaxpr_known, _, cond_uk, _ = pe.partial_eval_jaxpr_nounits(
#    1963     cond_jaxpr, cond_consts_uk + carry_uk, instantiate=False)
#    1965 if cond_uk[0] or all(not uk for uk in unknowns) or all(unknowns):
#    1966   # If conditional is unknown, or all inputs are known, or all are unknown,
#    1967   # just do the default processing.
# -> 1968   return trace.default_process_primitive(while_p, tracers, params)
#    1970 # Run the known part of the while.
#    1971 in_consts = [t.pval.get_known() for uk, t in
#    1972              zip(cond_consts_uk + body_consts_uk + carry_uk, tracers)
#    1973              if not uk]
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:249, in JaxprTrace.default_process_primitive(self, primitive, tracers, params)
#     246 if primitive.multiple_results:
#     247   out_tracers = [JaxprTracer(self, PartialVal.unknown(aval), None)
#     248                  for aval in out_aval]
# --> 249   eqn = new_eqn_recipe(self, tracers, out_tracers, primitive, params, effs,
#     250                        source)
#     251   if effects.partial_eval_kept_effects.filter_in(effs):
#     252     self.effect_handles.append(EffectHandle(tracers, eqn))
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:772, in new_eqn_recipe(trace, in_tracers, out_tracers, primitive, params, effects, source_info, ctx)
#     768   assert ("in_axes" in params and
#     769           len(params["in_axes"]) == len(params["call_jaxpr"].invars))
#     770   assert ("donated_invars" in params and
#     771           len(params["donated_invars"]) == len(params["call_jaxpr"].invars))
# --> 772 out_avals = [t.aval for t in out_tracers]
#     773 ctx = ctx or JaxprEqnContext(
#     774     compute_on.current_compute_type(),
#     775     config.threefry_partitionable.value,
#     776     xla_metadata_lib.current_xla_metadata(),
#     777 )
#     778 return JaxprEqnRecipe(next(trace.counter), tuple(in_tracers), map(ref, out_tracers),
#     779                       out_avals, primitive, params, effects, source_info,
#     780                       ctx)
#
# File ~/Documents/MIT/UROP_1/Work/.venv/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:570, in JaxprTracer.aval(self)
#     567 def __repr__(self):
#     568   return f'Traced<{self.aval}:{self._trace}>'
# --> 570 @property
#     571 def aval(self) -> AbstractValue:
#     572   return self.pval.get_aval()
#     574 @property
#     575 def parents(self) -> Sequence[JaxprTracer]:
#
# KeyboardInterrupt:

# %%
def fn_1(x):
    return x + 1

def fn_2(x):
    return x - 1

A = [fn_1, fn_2]
x = np.array(0)
# Out:
# Array([[0, 2],
#        [1, 4]], dtype=int64)

# %%
test = dict(a=9, b="Nope")
print(test)
# Out:
# {'a': 9, 'b': 'Nope'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 test = dict(a=9, b="Nope")
#       2 print(test)
# ----> 3 test.a
#
# AttributeError: 'dict' object has no attribute 'a'
